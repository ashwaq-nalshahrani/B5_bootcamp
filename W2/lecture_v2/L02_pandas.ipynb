# %% [markdown]
# # Pandas Fundamentals

# %% [markdown]
# **Pandas** provides fast, flexible, and expressive data structures designed to make working with “relational” or “labeled” data both easy and intuitive. It is built on top of **NumPy**, which is built on top of **C**. So, it is really fast.
#
# **Pandas Tutorial Notebooks**:
#
# 1. [Tutorial: Words Per Minute (01_wpm.ipynb)](../scenario/01_wpm.ipynb) (~30 min) explained by trainer
# 2. [Tutorial: Census (02_census.ipynb)](../scenario/02_census.ipynb) (~40 min) first read by learner, then, explained by trainer
# 3. [Exercise: Automobile Dataset](../exercises/ex_01_pandas_automobile/automobile_exercise.ipynb) (~35 min) attempted by learner, while trainer circles around for help
# 4. [Tutorial: Function Application (03_pd_function_application.ipynb)](../scenario/03_pd_function_application.ipynb) (~20 min) explained by trainer
#
# **References** to use while working with Pandas:
#
# - [Cheat Sheet](https://pandas.pydata.org/Pandas_Cheat_Sheet.pdf)
# - [Methods' Mind Map](https://xmind.ai/share/ugVH30g4)

# %% [markdown]
# After these notebooks, we will look at:

# %% [markdown]
# **Homework**: suggested reading from the Pandas documentation (~3 hours):
#
# 1. [10 Minutes to Pandas](https://pandas.pydata.org/docs/user_guide/10min.html).
# 2. [Intro to data structures](https://pandas.pydata.org/docs/user_guide/dsintro.html)
# 3. [Essential basic functionality](https://pandas.pydata.org/docs/user_guide/basics.html)
